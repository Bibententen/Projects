# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Market Intelligence Officer_TASK_agent_sample (1).xlsx')

# %% [markdown]
# # **EDA**

# %%
df.head()
# Out:
#    Application_Id  Applicant_Id Citizenship_Country       Birth_Country  \
# 0         1000001         10002               INDIA               INDIA
# 1         1000002         10006               NEPAL               NEPAL
# 2         1000003         10015  KOREA, REPUBLIC OF  KOREA, REPUBLIC OF
# 3         1000004         10020               NEPAL               NEPAL
# 4         1000005         10021            PAKISTAN            PAKISTAN
#
#   Current_Home_Country             Agent_Name       Agent_Country  \
# 0                INDIA               Agentium               INDIA
# 1            AUSTRALIA    Institute Education           AUSTRALIA
# 2   KOREA, REPUBLIC OF  Gain Education Global  KOREA, REPUBLIC OF
# 3                NEPAL    Institute Education           AUSTRALIA
# 4             PAKISTAN        Education Quest           AUSTRALIA
#
#   Application_Submission_Date Current_Application_Status  \
# 0                  2021-03-10                     Lapsed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Application_Id                211 non-null    int64
#  1   Applicant_Id                  211 non-null    int64
#  2   Citizenship_Country           211 non-null    object
#  3   Birth_Country                 211 non-null    object
#  4   Current_Home_Country          211 non-null    object
#  5   Agent_Name                    205 non-null    object
#  6   Agent_Country                 205 non-null    object
#  7   Application_Submission_Date   211 non-null    datetime64[ns]
#  8   Current_Application_Status    211 non-null    object
#  9   Last_Application_Status_Date  211 non-null    datetime64[ns]
#  10  Admission_Code                211 non-null    object
#  11  Course_Code                   211 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Application_Id                  0
# Applicant_Id                    0
# Citizenship_Country             0
# Birth_Country                   0
# Current_Home_Country            0
# Agent_Name                      6
# Agent_Country                   6
# Application_Submission_Date     0
# Current_Application_Status      0
# Last_Application_Status_Date    0
# Admission_Code                  0
# Course_Code                     0
# Course_Name                     0
# Course_Campus                   0
# Study_Mode                      0
# Intake_Study_Session_Code       0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Application_Id  Applicant_Id Citizenship_Country Birth_Country  \
# 7           1000008         10028         PHILIPPINES   PHILIPPINES
# 28          1000029         10089         PHILIPPINES   PHILIPPINES
# 29          1000030         10092         PHILIPPINES   PHILIPPINES
# 35          1000036         10113         PHILIPPINES   PHILIPPINES
# 56          1000057         10196         PHILIPPINES   PHILIPPINES
# 210         1000211         10715         PHILIPPINES   PHILIPPINES
#
#     Current_Home_Country Agent_Name Agent_Country Application_Submission_Date  \
# 7            PHILIPPINES        NaN           NaN                  2021-04-01
# 28           PHILIPPINES        NaN           NaN                  2021-07-22
# 29           PHILIPPINES        NaN           NaN                  2021-07-24
# 35           PHILIPPINES        NaN           NaN                  2021-08-04
# 56           PHILIPPINES        NaN           NaN                  2021-08-29
# ...

# %%
df[['Agent_Name', 'Agent_Country']] = df[['Agent_Name', 'Agent_Country']].fillna('Unknown')

# %% [markdown]
# # **Data Transformation**

# %%
df.head()
# Out:
#    Application_Id  Applicant_Id Citizenship_Country       Birth_Country  \
# 0         1000001         10002               INDIA               INDIA
# 1         1000002         10006               NEPAL               NEPAL
# 2         1000003         10015  KOREA, REPUBLIC OF  KOREA, REPUBLIC OF
# 3         1000004         10020               NEPAL               NEPAL
# 4         1000005         10021            PAKISTAN            PAKISTAN
#
#   Current_Home_Country             Agent_Name       Agent_Country  \
# 0                INDIA               Agentium               INDIA
# 1            AUSTRALIA    Institute Education           AUSTRALIA
# 2   KOREA, REPUBLIC OF  Gain Education Global  KOREA, REPUBLIC OF
# 3                NEPAL    Institute Education           AUSTRALIA
# 4             PAKISTAN        Education Quest           AUSTRALIA
#
#   Application_Submission_Date Current_Application_Status  \
# 0                  2021-03-10                     Lapsed
# ...

# %%
df.groupby('Agent_Country').size()
# Out:
# Agent_Country
# AUSTRALIA             159
# HONG KONG               1
# INDIA                  38
# KOREA, REPUBLIC OF      2
# NEPAL                   5
# Unknown                 6
# dtype: int64

# %%
df['Course_Campus'].value_counts()
# Out:
# Port Macquarie Campus    64
# Bathurst Campus          53
# Albury-Wodonga Campus    45
# Wagga Wagga Campus       28
# Online                   11
# Orange Campus             6
# Holmesglen                2
# Multi-Campus              2
# Name: Course_Campus, dtype: int64
